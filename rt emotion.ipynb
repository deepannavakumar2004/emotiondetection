# %%
import cv2

# %%
# !pip install deepface
# Out:
# ...
#   Using cached deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# ...
#   Using cached mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached fire-0.7.0-py3-none-any.whl
# ...
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached lz4-4.4.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# ...
# Using cached deepface-0.0.93-py3-none-any.whl (108 kB)
# Using cached flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
# Using cached retina_face-0.0.17-py3-none-any.whl (25 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# ...

# %%
# !pip install tf-keras
from deepface import DeepFace
# Out:
# ...
#   Using cached tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached tf_keras-2.18.0-py3-none-any.whl (1.7 MB)
# ...
# WARNING:tensorflow:From C:\Users\Deepn\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img=cv2.imread('sad.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
pred = DeepFace.analyze(img, actions=["emotion"], enforce_detection=False)

# %%
pred
# Out:
# [{'emotion': {'angry': np.float32(3.5319667),
#    'disgust': np.float32(4.460434e-05),
#    'fear': np.float32(13.875204),
#    'happy': np.float32(3.879089e-05),
#    'sad': np.float32(72.649475),
#    'surprise': np.float32(0.00052332313),
#    'neutral': np.float32(9.942749)},
#   'dominant_emotion': 'sad',
#   'region': {'x': 215,
#    'y': 194,
#    'w': 324,
#    'h': 324,
#    'left_eye': (431, 329),
#    'right_eye': (311, 324)},
#   'face_confidence': np.float64(0.9)}]

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tf-keras
# Out:
# ...
#   Using cached tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached tf_keras-2.18.0-py3-none-any.whl (1.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from deepface import DeepFace
facecascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap=cv2.VideoCapture(1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
while True:
    ret,frame=cap.read()
    cv2.imshow("Frame", frame)
    cv2.waitKey(1)  # Press 'q' to quit

    result_type = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=facecascade.detectMultiScale(gray,1.1,4)
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    font=cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,result_type[0]['dominant_emotion'],(50,50),font,3,(0,0,255),2,cv2.LINE_4)
    cv2.imshow('Original Video',frame)
    if cv2.waitKey(2) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
from deepface import DeepFace

# build model once
model = DeepFace.build_model("Facenet")
# Out:
# 25-03-02 22:30:18 - facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: C:\Users\Deepn\.deepface\weights\facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [01:03<00:00, 1.46MB/s]

# %%
pip install --upgrade deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import deepface.modules.modeling as dm
print(dir(dm))
# Out:
# WARNING:tensorflow:From c:\Users\Deepn\anaconda3\envs\aienv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ['Age', 'Any', 'ArcFace', 'CenterFace', 'DeepID', 'Dlib', 'DlibDetector', 'Emotion', 'Facenet', 'FasNet', 'FastMtCnn', 'FbDeepFace', 'Gender', 'GhostFaceNet', 'MediaPipe', 'MtCnn', 'OpenCv', 'OpenFace', 'Race', 'RetinaFace', 'SFace', 'Ssd', 'VGGFace', 'Yolo', 'YuNet', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'build_model']
